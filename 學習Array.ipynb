# %% [markdown]
# <a href="https://colab.research.google.com/github/will20090425-eng/App-Inventor/blob/main/%E5%AD%B8%E7%BF%92Array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **創造 你的第3個Apps，Create Apps**

# %% [markdown]
# 1.   登入 google gmail
# 2.   google: app inventor 找到 https://appinventor.mit.edu/
# 3.   創造 Apps，**Create Apps!**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Project name: **Array**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 選擇手機型號

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 外觀設計**Designer**

# %% [markdown]
# **Layer**
#
# *   **TableArrangement**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Screen1**: AlignHorizontal 選 Center

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Columns: 3，Rows: 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9個Button: Button1，Button2,...,Button9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Layout: HorizontalArrangement，屬性
#
#
# *   AlignVertical: Center
# *   Height: 20 percent （符號為%）

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3個Button: Button10，Button11, Button12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Button10.BackgroundColor = **Red**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Button11.BackgroundColor = **Green**，Button12.BackgroundColor = **Blue**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 程式設計**Block**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 請用 Gemini AI，這種程式設計好嗎?
#
# *   為何不好
# *   如何解構
# *   還可以進一步使用 procedure改善(是一組執行特定任務的指令。它也可以稱為函數)

# %% [markdown]
# create empty list，增加空容器: buttonsList，準備放 9個Button: Button1，Button2,...,Button9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Screen1.Initialize

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# add items( button1-button9) to list:buttonsList

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# add **9個** items

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9個items，再按一次深藍色，如下紅框，增加視窗會消失

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# add items button1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ctrl+C，Ctrl+V，8次

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 選合適的 button2-button9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 用 Gemini AI，尋問

# %% [markdown]
# for each item，以及，set Button.? of component，意義為何?如何使用?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **可以用 procedure改善，再簡化**
#
# 可以進一步使用 procedure改善(是一組執行特定任務的指令。它也可以稱為函數)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 學習心得
#
# 學到如何利用MIT app inventor製作app並用block寫程式

# %% [markdown]
# # 存入

# %% [markdown]
# ![image.png](data:image/png;base64,...)
