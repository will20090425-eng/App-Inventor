# %% [markdown]
# <a href="https://colab.research.google.com/github/will20090425-eng/App-Inventor/blob/main/%E5%AD%B8%E7%BF%92Click3Times.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **創造 你的第2個Apps，Create Apps**

# %% [markdown]
# 1.   登入 google gmail
# 2.   google: app inventor 找到 https://appinventor.mit.edu/
# 3.   創造 Apps，**Create Apps!**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **新專案 New project**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Project name: Click3Times**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **選手機型號**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **請回答是否完成?**
#
# ---

# %% [markdown]
# #  HelloPurr：輕拍小貓，聽它喵喵叫，按三次， **超過3次，手機，會說"按超過 ?次"**
#
# 請參考官方教學 [連結文字](https://appinventor.mit.edu/explore/ai2/hellopurr)
#
# 或參考老師的教學 [連結文字](https://github.com/PeterShiaush/AppInventorRepo)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **設計外觀 Disigner**

# %% [markdown]
# 您需要一張**貓的圖片檔案** 和一個 **「喵」的音訊檔案**。**右鍵單擊**以下鏈接，選擇“鏈接另存為…”即可將這些文件下載到您的電腦。將這兩個檔案儲存到桌面、下載資料夾或其他方便您日後查找的位置。
#
# **小貓圖片**：kitty.png（右鍵並儲存）[連結文字](https://appinventor.mit.edu/explore/sites/all/files/ai2tutorials/helloPurr/kitty.png)
#
# **喵喵聲**：meow.mp3（右鍵另存為）[連結文字](https://appinventor.mit.edu/explore/sites/all/files/ai2tutorials/helloPurr/meow.mp3)
#
# 請參考官方教學 [連結文字](https://appinventor.mit.edu/explore/ai2/hellopurr)
#
# 或參考老師的教學 [連結文字](https://github.com/PeterShiaush/AppInventorRepo)

# %% [markdown]
# 拖曳
#
# 1.   Button **1個** 加入 image: kitty.png
# 2.   Label **2個** 修改屬性
# 3.   Sound **1個** 加入 source: meow.mp3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 開啟 **Media**，拖曳 **TextToSpeech** 到 Screen1，手機外面的底部出現  **TextToSpeech1**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 請檢查 **5個物件**，如下:
#
# 1.   Button**1**
# 2.   Label**1**
# 3.   Label**2**
# 4.   Sound**1**
# 5.   **T**ext**T**o**S**peech**1**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **請回答是否完成?**
#
#
# ---

# %% [markdown]
# # **程式設計 Blocks**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **認識變數**

# %% [markdown]
# **設定變數 Varialbles**
# *   選 **Varialbles**
# *   拖曳 **initialize global**
# *   name 改為 **myCounter**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **設定變數的數值 myCounter = 0**
# *   選 **Math**
# *   拖曳 **0**
# *   **myCounter** 設定為 **0**　　(非常重要，myCounter = 0 **不是**數學等式)
# *   而是　myCounter **<=** 0 **，將 0 存入myCounter** )

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **初始 Screen1 該做哪些事情?**
#
# *   選 **Screen1**
# *   拖曳 **when Screen1. Initialize**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **該做設定Label2的數值文字**
#
# *   選 **Label2**
# *   拖曳 **set Label2.Text**　(設定Label2的文字Text)
# *   到**when Screen1. Initialize**的裡面

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **領取 get myCounter 數值，設定 Label1.Text**
#
# *   選 **myCounter**
# *   選並拖曳 **get  myCounter**　(選定myCounter的數值 0 )
# *   到**set Label1.Text**的後面　(**Label1.Text = myCounter**，注意!不是數學等式，而是　**Label1.Text <= myCounter**)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Button1設定 Click 按下觸發的事情**
#
# *   選 **Button1**
# *   選並拖曳 **Button1.Click**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **觸發 myCounter + 1**
#
# *   選 **Math**
# *   拖曳　 **+**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **get myCounter + 1**
#
# *   選 **myCounter**
# *   拖曳　 **get myCounter**
# *   **Math** 中拖曳**整數 0** ，再改為　 1　(**myCounter + 1**)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **設定 set myCounter**
#
# *   選 **myCounter**
# *   拖曳　 **set myCounter**
# *   接上**myCounter + 1** 　(**myCount = myCounter + 1，myCount <= myCounter + 1**)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **加入 Sound1.Play，檢查是否如下圖**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **請回答是否完成?**
#
# ---

# %% [markdown]
# **在set Label2按滑鼠右鍵**
#
# *   選複製 **Duplicate**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   拖曳複製的　 **set Label2**
# *   接上**Button1.Click** 　(**Label1.Text = myCounter **)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **想想，如果 Button1 被按下(Click)**
#
# *   myCounter **被** 設定為 **拿? + 1**
# *   Sound1.**Play** 　　**意義是?**
# *   **Label2的文字**被設定為 **???**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **增加樂趣，如果加入 TextToSpeech1， 發出message文字聲音**
#
# *   **TextToSpeech1** 選定拖曳 Call TextToSpeech1.Speak
# *   **發出message文字聲音**，message文字聲音，被設定???

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **加入 Label1的Text 文字，到message**
#
# *   message文字聲音被設定為 **Label1Text** 的

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 拖曳 Text 的 join，擴張為 **3個字串**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 拖曳 **Label2.Text**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 完成如下，請檢查!!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **請回答是否完成?**
#
# ---

# %% [markdown]
# **手機測試第一階段**
#
# *   手機新增 App
# *   android 手機https://play.google.com/store/apps/details?id=edu.mit.appinventor.aicompanion3&hl=zh_HK
# *   iPhone 手機https://apps.apple.com/tw/app/mit-app-inventor/id1422709355

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)

# %% [markdown]
# **手機測試第二階段**
#
# *   點選手機上圖的App，開啟 App
# *   點選 **scan QR code**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **手機測試第三階段**
#
# *   點選 專案上的 Connect 連線，開啟 App
# *   以手機 App scan QR code

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **完成Blocks初步學習**
#
#
# *   整數變數 + 1
# *   標籤展示，整數變數的變化
# *   文字生成聲音
# *   手機展示成功

# %% [markdown]
# **請回答是否完成?**
#
# ---

# %% [markdown]
# # **進階自學 if then else**
#
# *   **如(if)**
# *   **則(then)**
# *   **其他(else)**

# %% [markdown]
# **按Button1，myCounter + 1**
#
# 如(if) 小於等於3次
#
# 則(then)　 　正常發音
#
# 其他(else)　 "按超過"+"?"+"次"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 如(if) **小於等於3次**
#
# 則(then)　 　正常發音
#
# 其他(else)　 "按超過"+"?"+"次"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 完成程式碼，如下圖

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **請回答是否完成?**
#
# ---

# %% [markdown]
# #  **進階冒險**，HelloPurr：輕拍小貓，，
#
# *   按3次以內，聽它喵喵叫，
# *   **超過3次**，手機，會說"按超過 ?次"
# *   **超過10次**，手機，會說"???????"

# %% [markdown]
# # 簡要學習心得
#
# 1.   學習if then else
# 2.   學習心得

# %% [markdown]
# # **自學 github**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **New** 新增一個 **repository**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Repository name: **AppInventorRepo**
# No.gitignore: **Python**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 檢查是否有 **AppInventorRepo**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 在GitHub中儲存副本

# %% [markdown]
# ![image.png](data:image/png;base64,...)
